# %% [markdown]
# # 01 - Exploratory Data Analysis (EDA)
#
# ## Student Grade Prediction Dataset
#
# This notebook performs comprehensive exploratory data analysis on the Student Grade Prediction dataset from Kaggle.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

# %% [markdown]
# ## 2. Load Data

# %%
df = pd.read_csv('../data/raw/student-grades.csv')
print(f'✓ Data loaded: {df.shape}')

# %% [markdown]
# ## 3. First Look at Data

# %%
df.head()

# %% [markdown]
# ## 4. Data Info

# %%
df.info()

# %% [markdown]
# ## 5. Descriptive Statistics

# %%
df.describe()
